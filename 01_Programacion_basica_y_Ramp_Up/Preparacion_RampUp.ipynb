# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## TIPS PARA PROGRAMAR PYTHON

# %% [markdown]
# **1.** Si te lías usa siempre variables intermedias en vez de hacerlo todo en una sola línea:
#
# ```python
# nombre = "Natividad"
# # En vez de
# pizz_mediana = int(round(input(f"¿Cuántas pizzas quieres, {nomre}?")))
# # empieza con algo más "verbose" o farragoso:
# mensaje = f"¿Cuántas pizzas quieres {nombre}"
# pizz_mediana = input(mensaje)
# redondeo = roun(pizz_mediana)
# pizz_mediana_num = int(redondeo)
# ```
#
# Con el tiempo te lo saltarás pero de primeras te permitirá seguir mejor el código.
#
# **2.** ¿Cuándo usar `for`? Generalmente:
#
# - Cuando tengas que repetir código un número limitado de veces o hacerlo recorriendo una lista, diccionario, tupla, etc.
# - Si el código que tienes que repetir quieres volver a usarlo más adelante, incluyelo en una función
#
# **3.** ¿Cuándo usar `while`? Generalmete:
#
# - Cuando tengas que repetir códigó un número indefinido de veces hasta que se cumpla una condición.
# - Para salir del while recuerda o poner la comprobación de salida detrás del while <comprobación de la condición> == False o dentro del bucle con un break:
#     if condición de salida:
#         break
#
# **4.** Cuando usar `range`:
#
# - Cuando tengas que repetir n veces un código y no sea para recorrer una lista, sino que sólo te importe llevar la cuenta de en cuál repetición estás.
# - Recuerda que en un bucle for puedes ponerlo tal cual:
# ```python
# # El siguiente for imprimira del 0 al 4 en líneas separadas
# for i in range(5):
#     print(i)
# # Y es equivalente a
# for i in range(0,5):
#     print(i)
# ```
#
#
# **5.** Cuando usar `enumerate`:
# - Cuando tengas que recorrer una colección (lista, tupla, etc) y quieras tener además de cada uno de los valores de la colección el índice a ese valor. Por ejemplo para recorrer una lista principal con el for y otra "en paralelo" con el indice.
#
#
# **6.** Cuando usar `items` (para diccionarios):
# - Cuando quieras recorrer los valores de un diccionario y sus claves y quieras o necesites tener las dos cosas a la vez. La clave y el valor asociado.
#
# **7.** El uso de `in``:
# - Cuando tengas que comprobar si una valor pertenece a una lista, tupla, string, set, no crees un for para recorrerla secuencialmente y comprobar si esta el valor, utiliza in.Por ejemplo:
#     if  <valor que queremos comprobar> in <lista, tupla, etc en la que queremos comprobarlo>:
# - Si queremos comprobar que "NO" está:
#     if <valor que queremos comprobar> not in <lista,, tupla, etc>:
# - Puedes asignar la condición a una variable, y luego emplearla más adelante o en el propio if/elif:
#     variable = <valor que queremos comprobar> in <lista, tupla, etc en la que queremos comprobarlo>
#     if variable:
#     ...
#
# **8.** Recuerda:
# - Todas las funciones devuelven algo, si no has puesto return en el código de tu función, esta devolverá `None``.
# - print imprime por pantalla pero devuevle `None``:
#     ```Python
#     hola = print("Hola") # imprimirá "Hola" por pantalla, pero asignará None a la variable hola.
#     print(hola) # imprimira `None`
#     ```
# - Las variables van tal cual, los strings entre comillas: hola no es "hola".
# - Los métodos de las cadenas no modifican las cadenas/variables que las llaman:
#     variable = "hola"
#     variabe.replace("h","s") -> devuelve "sola", pero variable seguirá conteniendo "hola"
# - Los métodos de las listas suelen modificar la lista que los usa y devuelven None:
# ```Python
#     lista = [1,7,5,3]
#     lsita_2 = lista.sort()
#     print(lista) # imprimira [1,3,5,7]
#     print(lista_2) # imprimira None
# ```

# %% [markdown]
# ## RESUMENES

# %% [markdown]
# ### Variables, print, del, tipos, conversion, None, input

# %%
# Declarar variables
var = 10

# Reasignar valores
var = 12

# Imprimir por pantalla
print("Primera linea")
print("Variable declarada es:", var)
print("Variable declarada es: %s" %(var))

"""
Comentarios
Multilínea
"""

# Eliminar variables
del var

# Tipos de datos
print("\n") # Simplemente para que haya un salto de linea en el output
print(type(1)) # Int
print(type(1.0)) # Float
print(type("1")) # String
print(type(True)) # Boolean

# Conversiones de tipos
print("\n")
var2 = 4
print(type(var2))
var2 = str(var2)
print(type(var2))
var2 = bool(var2)
print(type(var2))

# El valor nulo
print(None)

# Input de variables
var3 = input("Inserta variable ")

# %% [markdown]
# ### Operaciones matemáticas, comparativas, booleanos, funciones built-in, listas

# %%
# Operaciones matemáticas
print("Operaciones matemáticas")
print(4 + 6)
print(9*2)
print(2 * (3 + 5))
print(10/5)
print(10 % 3)
print(2**10)

# Funciones matemáticas más complejas
import math
print(math.sqrt(25))


# Operaciones comparativas
print("\nOperaciones comparativas")
print("AAA" == "BBB")
print("AAA" == "AAA")
print(1 == 1)
print(1 == 1.0)
print(67 != 93)
print(67 > 93)
print(67 >= 93)


# Operaciones con booleanos
print("\nOperaciones con booleanos")
print(True and True and False)
print(True or True or False)
print(not False)


# Funciones builtin
print("\nFunciones built-in")
string_builtin = "Fin del notebook"
print(string_builtin.upper())
print(string_builtin.lower())
print( string_builtin.replace("o", "O"))
print(string_builtin.replace("o", ""))


# Listas
print("\nListas")
musica = ["AC/DC", "Metallica", "Nirvana"]
musica.append("Queen")
print(musica)

# %% [markdown]
# ### Flujos de Control

# %%
# If/elif/else
mi_nota_de_examen = 7

if mi_nota_de_examen < 5 :
    print("A septiembre :(")

elif mi_nota_de_examen < 6 :
    print("Suficiente")
    
elif mi_nota_de_examen < 7 :
    print("Bien")
    
elif mi_nota_de_examen < 9 :
    print("Notable")
    
else:
    print("Sobresaliente")
    
    
# Bucle for
dias_semana = ["Lunes", "Martes", "Miércoles", "Jueves", "Viernes", "Sábado", "Domingo"]

for dia in dias_semana:
    print(dia)
    
    
# Bucle while
i = 0

while(i < 5):
    print(i)
    i = i + 1
    
    
# Break y continue
for val in "string":
    if val == "i":
        break
    print(val)

print("Fin")


# Try/except
try:
  print(variable_)
except:
  print("El codigo tiene errores porque la variable 'variable_' no existe")

print("Continuo con el programa")

# %% [markdown]
# ### Listas

# %%
# Listas
print("Listas")
nums = [6, 2, 8, 3, 4, 5, 5]

# Tamaño
print(len(nums))

# Acceso
print(nums[2])
print(nums[-1])

# Acceso por indice
print(nums.index(5))
nums.append('numeros')
print(nums)

# Eliminar
nums.remove("numeros")
print(nums)

# Ordenar
nums.sort()
print(nums)

# Tamaño de la lista
print(len(nums))

# Invertir el orden
nums.reverse()
print(nums)

# Ocurrencia de un valor
print(nums.count(22))

# %% [markdown]
# ### Tuplas

# %%
# Tuplas
primera_tupla = (3, "text")

# Anidacion de tuplas
tupla_anid = (1, 2, 3, ("A", "B", "C"))
print(tupla_anid)

# El acceso es como en las listas
print(tupla_anid[0])

# Tambien son elementos iterables
for i in tupla_anid:
    print(i)
    
# El slicing también funciona igual
print(tupla_anid[0:2])

# Longitud de la tupla
print(len(tupla_anid))

# %% [markdown]
# ### Diccionarios

# %%
# Diccionario
coche = {"color": "Gris",
        "marca": "VW",
        "peso": 1500,
        "Cambio automatico": True}

print(coche)

coche = {"color": "Gris",
        "marca": "VW"
        }

for i in coche: # Esta recorriendo las claves
    print(i) # Imprimimos la clave
    print(coche[i]) # Imprimimos el valor
    
# Otra menera de recorrer los elementos
for clave, valor in coche.items():
    print(clave, valor)

# %% [markdown]
# ### Sets

# %%
# Sets
colores = {"rojo", "azul", "blanco"}
print(colores)

# Mira lo que ocurre cuando ponemos duplicados
colores2 = {"rojo", "azul", "blanco", "rojo"}
print(colores2)

# El len tambien funciona aqui
len(colores2)

# Crear un set vacio. No se crea con {}, ya que si no, sería un diccionario.
dias = set()
print(dias)

# Añadir elementos
dias.add("Lunes")
dias.add("Martes")
dias.add("Miercoles")
print(dias)

# Eliminar elementos
dias.remove("Miercoles")
print(dias)

# Buscar elementos
print("Lunes" in dias)
print("Viernes" not in dias)

# Tambien es un iterable
for i in dias:
    print(i)

# %% [markdown]
# ### Funciones

# %%
# Una funcion tiene la siguiente sintaxis
def km_millas(distancia):
    millas = distancia * 0.62
    return millas

# La podemos llamar cuántas veces queramos
print(km_millas(2))
print(km_millas(5))
print(km_millas(10))

# Las funciones pueden tener argumentos posicionales
def multipl(x1, x2, x3, x4):
    return (x1 * x2 * x3) / x4

multipl(4,6,7,2)

# Argumentos variables
def multipl_var(*args):
    print(type(args))
    mult_tot = 1
    
    for i in args:
        mult_tot = mult_tot * i
        
    return mult_tot


multipl_var(4,5,6,3)


# Argumentos con formato clave valor
def movil(**kwargs):
    
    print(type(kwargs))
    for key, value in kwargs.items():
        print(key, "=", value)
        
    return kwargs

# Llamamos a la funcion
print(movil(Camara = "24MPx",
           Bateria = 10,
           Peso = 200))


# Argumentos keyword
def venta_online(pedido, fecha_entrega, incidencia = False):
    
    if(incidencia):
        print("Contacte con Att. Cliente")
        
    else:
        print("Su pedido", pedido, "se entregará el", fecha_entrega)
        
venta_online("AAA", "20-07-2020")
venta_online("AAA", "20-07-2020", True)



# Las funciones se documentan con el atributo docstring
def multiplica(x,y):
    """
    Funcion que multiplca los dos argumentos: x*y
    """
    print("Empieza la funcion")
    # Mas comentarios
    
    return x*y

print(multiplica(2,2))
print(multiplica.__doc__)

# %% [markdown]
# ## TIPS PARA PRESENTAR Y COMENTAR CODIGO

# %% [markdown]
# ### Los de Jaime
# - Las definiciones de función arriba
# - Despues las variables que asignemos inicialmente al programa
# - Luego nuestro código principal
# - No uses nombres raros y usa "snake_case" para las variables palabra1_palabra2_palabra3, por ejemplo:
# ```python
# esta_es_una_variable_snake_case = "serpiente"
# ```
# - Y no uses espacios en los nombres de ficheros ni directorios (grita conmigo!!!)

# %% [markdown]
# ### Los que tienes en los notebooks

# %% [markdown]
# A la hora de escribir en Python, existen ciertas normas que hay que tener en cuenta:
# * Todo lo que abras, lo tienes que cerrar: paréntesis, llaves, corchetes...
# * Los decimales se ponen con puntos `.`
# * Best practices
#     * **Caracteres**: NO se recomienda usar Ñs, acentos o caracteres raros (ª,º,@,ç...) en el codigo. Ponerlo únicamente en los comentarios.
#     * **Espacios**: NO usar espacios en los nombres de las variables ni de las funciones. Se recomienda usar guión bajo para simular el espacio. O también juntar las palabras y usar mayuscula para diferenciarlas `miVariable`. Lo normal es todo minúscula y guiones bajos
#     * Ahora bien, sí se recomienda usar espacios entre cada comando, para facilitar la lectura, aunque esto ya es más cuestión de gustos. `mi_variable = 36`.
#     * Se suelen declarar las variables en minuscula.
#     * Las constantes (variables que no van a cambiar nunca) en mayuscula. `MI_PAIS = "España"`
#     * **Cada sentencia en una linea**. Se puede usar el `;` para declarar varias variables, pero no es lo habitual
#     * **Comentarios**: TODOS los que se pueda. Nunca sabes cuándo otra persona va a coger tu espectacular código, o si tu *yo* del futuro se acordará de por qué hiciste ese bucle while en vez de un for.
#     * **Case sensitive**: sensible a mayusculas y minusculas. CUIDADO con esto cuando declaremos variables o usemos Strings
#     * **Sintaxis de línea**: para una correcta lectura del codigo lo mejor es aplicar sintaxis de línea en la medida de lo posible

# %% [markdown]
# ## CONSEJOS BASICOS, CORTESIA DE CHATGPT

# %% [markdown]
# 1. **Aprende lo Básico Primero**: Antes de sumergirte en proyectos complejos, asegúrate de tener una buena comprensión de los fundamentos de Python. Esto incluye variables, tipos de datos, operadores, estructuras de control (como bucles y condicionales), y funciones. También es útil familiarizarte con las listas, tuplas, y diccionarios, ya que son tipos de datos muy utilizados en Python.
#
# 2. **Practica Regularmente**: La programación es una habilidad que mejora con la práctica. Trata de escribir un poco de código todos los días, incluso si es solo por unos minutos. Puedes resolver problemas de programación en sitios web como LeetCode, HackerRank, o CodeSignal. Estos sitios ofrecen problemas que puedes resolver utilizando Python, y te dan la oportunidad de mejorar tus habilidades de programación.
#
# 3. **Trabaja en Proyectos Pequeños**: Una vez que tengas una comprensión básica de Python, comienza a trabajar en proyectos pequeños y manejables. Esto podría ser algo tan simple como un programa que calcula la media de una lista de números, o un script que renombra archivos en un directorio. Trabajar en proyectos pequeños te ayudará a aplicar lo que has aprendido y a desarrollar tu habilidad para resolver problemas.
#
# 4. **Lee Código de Otros**: Leer el código escrito por otros programadores es una excelente manera de mejorar tus habilidades de programación. Puedes aprender nuevas técnicas, ver diferentes estilos de codificación, y familiarizarte con las bibliotecas y frameworks de Python. GitHub es un buen lugar para encontrar proyectos de código abierto escritos en Python.
#
# 5. **No Temas Pedir Ayuda**: Si te encuentras atascado, no dudes en buscar ayuda. Hay una gran comunidad de programadores de Python que están dispuestos a ayudar. Puedes hacer preguntas en foros como Stack Overflow, Reddit, o incluso en grupos de Discord dedicados a la programación. Cuando pidas ayuda, trata de ser lo más claro y específico posible en tu pregunta, y proporciona cualquier código relevante.
#
# Recuerda que aprender a programar lleva tiempo, y está bien cometer errores mientras aprendes. ¡La clave es practicar regularmente y no rendirse!
